# %% [markdown]
# <a href="https://colab.research.google.com/github/bds51334/bte320/blob/main/bte320-Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello

# %%
interest= 0.03 # The percentage value
principal= 3000 # initial deposit
n=1 # Number of Years

final = principal * (1+interest) ** n

print(final)
# Out:
# 3090.0

# %%
print (interest, principal)
print (n)
# Out:
# 0.03 3000
# 1

# %%
print ("interest rate", interest, sep="=>")
print ("number of years", n)
# Out:
# interest rate=>0.03
# number of years 1

# %%
print ("ineterest rate", interest, end="...\n")
print ("Number of years:", n, sep="")
# Out:
# ineterest rate 0.03...
# Number of years:1

# %%
print("Interest rate:", interest, sep=">>>", end="&&&")
print("Number of years:", n)
# Out:
# Interest rate:>>>0.03&&&Number of years: 1
